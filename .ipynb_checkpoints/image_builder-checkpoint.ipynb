# %%
import pandas as pd
import numpy as np
from fastai.vision.all import *

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', 50)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
 #Enter desired years of data
YEARS = [2020]

data = pd.DataFrame()

for i in YEARS:  
    #low_memory=False eliminates a warning
    i_data = pd.read_csv('https://github.com/guga31bb/nflfastR-data/blob/master/data/' \
                         'play_by_play_' + str(i) + '.csv.gz?raw=True',
                         compression='gzip', low_memory=False)

    #sort=True eliminates a warning and alphabetically sorts columns
    data = data.append(i_data, sort=True)

#Give each row a unique index
data.reset_index(drop=True, inplace=True)

# %%
data['uid'] = data['game_id'] \
                + '-' + data['drive'].fillna(0).astype(int).astype(str) \
                + '-' + data['play_id'].astype(str)

# %%
data['play_id']
# Out:
# 0          1
# 1         39
# 2         54
# 3         93
# 4        118
#         ...
# 8757    4016
# 8758    4035
# 8759    4050
# 8760    4071
# 8761    4098
# Name: play_id, Length: 8762, dtype: int64

# %%
data['drive'].fillna(0).astype(int).astype(str)
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 8757    22
# 8758    22
# 8759    23
# 8760    23
# 8761    23
# Name: drive, Length: 8762, dtype: object

# %%
data[['uid','home_team','away_team','posteam','qtr','time'
                         ,'total_home_score','total_away_score'
          ,'down','ydstogo','yardline_100','ydsnet','play_type','yards_gained','desc','penalty','penalty_type','penalty_yards',
     'play_id','game_id','drive','old_game_id','shotgun']]\
.query('(away_team=="DAL")&'
       '(qtr==3) & (time=="13:34")' ).head(5)
# Out:
#                         uid home_team away_team posteam  qtr   time  \
# 658  2020_01_DAL_LA-10-2468        LA       DAL     DAL    3  13:34
#
#      total_home_score  total_away_score  down  ydstogo  yardline_100  ydsnet  \
# 658                13                14   3.0       10          56.0    21.0
#
#     play_type  yards_gained  \
# 658      pass          11.0
#
#                                                                                                     desc  \
# 658  (13:34) (Shotgun) 4-D.Prescott pass short middle to 86-D.Schultz to LA 45 for 11 yards (22-T.Hill).
#
#      penalty penalty_type  penalty_yards  play_id         game_id  drive  \
# 658      0.0          NaN            NaN     2468  2020_01_DAL_LA   10.0
#
#      old_game_id  shotgun
# 658   2020091312        1

# %%
import os

# %%
image_files = os.listdir('images')

# %%
image_play_indeces = [os.path.splitext(i)[0] for i in image_files]

# %%
image_play_indeces
# Out:
# ['2020_01_DAL_LA-1-122',
#  '2020_01_DAL_LA-1-196',
#  '2020_01_DAL_LA-1-296',
#  '2020_01_DAL_LA-1-77',
#  '2020_01_DAL_LA-10-2404',
#  '2020_01_DAL_LA-10-2468',
#  '2020_01_DAL_LA-2-351',
#  '2020_01_DAL_LA-2-417',
#  '2020_01_DAL_LA-3-560',
#  '2020_01_DAL_LA-3-648',
#  '2020_01_DAL_LA-3-672',
#  '2020_01_DAL_LA-3-717',
#  '2020_01_DAL_LA-8-2241',
#  '2020_02_BUF_MIA-1-122',
#  '2020_02_BUF_MIA-1-41',
#  '2020_02_BUF_MIA-18-3218',
#  '2020_02_BUF_MIA-18-3242',
#  '2020_02_BUF_MIA-18-3341',
#  '2020_02_BUF_MIA-19-3396',
#  '2020_02_BUF_MIA-19-3455',
#  '2020_02_BUF_MIA-2-193',
#  '2020_02_BUF_MIA-2-260',
#  '2020_02_BUF_MIA-3-327',
#  '2020_02_BUF_MIA-3-395',
#  '2020_02_BUF_MIA-3-419',
#  '2020_02_BUF_MIA-3-440',
#  '2020_02_BUF_MIA-3-511',
#  '2020_02_BUF_MIA-3-546',
#  '2020_02_BUF_MIA-4-602',
#  '2020_02_BUF_MIA-4-718',
#  '2020_02_BUF_MIA-4-766',
#  '2020_02_BUF_MIA-9-1456',
#  '2020_02_BUF_MIA-9-1480',
#  '2020_02_BUF_MIA-9-1673']

# %% [markdown]
# target_image is basically to define whether a play was shotgun or not.

# %%
target_image = data[data.uid.isin(image_play_indeces)][['shotgun','uid']]

# %%
def shotgun_labels(f): return target_image.loc[f].shotgun

# %%
shotgun_labels(image_play_indeces[5])
# Out:
# 1

# %%
target_image['fn'] = target_image.uid + '.png'

# %%
data.query("uid=='2020_01_DAL_LA-1-122'")
# Out:
#      aborted_play   air_epa   air_wpa  air_yards  assist_tackle  \
# 561             0 -1.216175 -0.013172       -4.0            0.0
#
#     assist_tackle_1_player_id assist_tackle_1_player_name  \
# 561                       NaN                         NaN
#
#     assist_tackle_1_team assist_tackle_2_player_id  \
# 561                  NaN                       NaN
#
#     assist_tackle_2_player_name assist_tackle_2_team  \
# 561                         NaN                  NaN
#
#      assist_tackle_3_player_id  assist_tackle_3_player_name  \
# 561                        NaN                          NaN
#
#      assist_tackle_3_team  assist_tackle_4_player_id  \
# 561                   NaN                        NaN
#
#      assist_tackle_4_player_name  assist_tackle_4_team     away_coach  \
# 561                          NaN                   NaN  Mike McCarthy
#
#      away_score away_team  away_timeouts_remaining   away_wp  away_wp_post  \
# 561          17       DAL                        3  0.402838      0.333529
#
#     blocked_player_id blocked_player_name  comp_air_epa  comp_air_wpa  \
# 561               NaN                 NaN     -1.216175     -0.013172
#
#      comp_yac_epa  comp_yac_wpa  complete_pass        cp       cpoe    def_wp  \
# 561      3.641983      0.082481            1.0  0.882457  11.754256  0.402838
#
#      defensive_extra_point_attempt  defensive_extra_point_conv  \
# 561                            0.0                         0.0
#
#      defensive_two_point_attempt  defensive_two_point_conv defteam  \
# 561                          0.0                       0.0     DAL
#
#      defteam_score  defteam_score_post  defteam_timeouts_remaining  \
# 561            0.0                 0.0                         3.0
#
#                                                                                         desc  \
# 561  (13:40) 16-J.Goff pass short left to 17-R.Woods to DAL 15 for 31 yards (23-D.Thompson).
#
#      div_game  down  drive drive_end_transition drive_end_yard_line  \
# 561         0   2.0    1.0            TOUCHDOWN               DAL 1
#
#      drive_ended_with_score  drive_first_downs drive_game_clock_end  \
# 561                     1.0                4.0                11:37
#
#     drive_game_clock_start  drive_inside20  drive_play_count  \
# 561                  15:00             1.0               7.0
#
#      drive_play_id_ended  drive_play_id_started  drive_quarter_end  \
# 561                296.0                   39.0                1.0
#
#      drive_quarter_start  drive_real_start_time drive_start_transition  \
# 561                  1.0                    NaN                KICKOFF
#
#     drive_start_yard_line drive_time_of_possession  drive_yards_penalized  \
# 561                 LA 25                     3:23                    5.0
#
#     end_clock_time end_yard_line        ep       epa  extra_point_attempt  \
# 561            NaN        DAL 15  2.900399  2.425808                  0.0
#
#      extra_point_prob extra_point_result   fg_prob  field_goal_attempt  \
# 561               0.0                NaN  0.284435                 0.0
#
#     field_goal_result  first_down  first_down_pass  first_down_penalty  \
# 561               NaN         1.0              1.0                 0.0
#
#      first_down_rush  fixed_drive fixed_drive_result  \
# 561              0.0            1          Touchdown
#
#     forced_fumble_player_1_player_id forced_fumble_player_1_player_name  \
# 561                              NaN                                NaN
#
#     forced_fumble_player_1_team forced_fumble_player_2_player_id  \
# 561                         NaN                              NaN
#
#     forced_fumble_player_2_player_name forced_fumble_player_2_team  \
# 561                                NaN                         NaN
#
#      fourth_down_converted  fourth_down_failed  fumble  fumble_forced  \
# 561                    0.0                 0.0     0.0            0.0
#
#      fumble_lost  fumble_not_forced  fumble_out_of_bounds  \
# 561          0.0                0.0                   0.0
#
#     fumble_recovery_1_player_id fumble_recovery_1_player_name  \
# 561                         NaN                           NaN
#
#     fumble_recovery_1_team  fumble_recovery_1_yards  \
# 561                    NaN                      NaN
#
#     fumble_recovery_2_player_id fumble_recovery_2_player_name  \
# 561                         NaN                           NaN
#
#     fumble_recovery_2_team  fumble_recovery_2_yards fumbled_1_player_id  \
# 561                    NaN                      NaN                 NaN
#
#     fumbled_1_player_name fumbled_1_team fumbled_2_player_id  \
# 561                   NaN            NaN                 NaN
#
#     fumbled_2_player_name fumbled_2_team   game_date game_half  \
# 561                   NaN            NaN  2020-09-13     Half1
#
#             game_id  game_seconds_remaining  game_stadium  goal_to_go  \
# 561  2020_01_DAL_LA                  3520.0  SoFi Stadium           0
#
#      half_seconds_remaining  home_coach  home_score home_team  \
# 561                  1720.0  Sean McVay          20        LA
#
#      home_timeouts_remaining   home_wp  home_wp_post  \
# 561                        3  0.597162      0.666471
#
#                                        id  incomplete_pass  interception  \
# 561  32013030-2d30-3033-3331-30361d564889              0.0           0.0
#
#     interception_player_id interception_player_name  jersey_number  \
# 561                    NaN                      NaN           16.0
#
#      kick_distance kicker_player_id kicker_player_name  kickoff_attempt  \
# 561            NaN              NaN                NaN              0.0
#
#      kickoff_downed  kickoff_fair_catch  kickoff_in_endzone  \
# 561             0.0                 0.0                 0.0
#
#      kickoff_inside_twenty  kickoff_out_of_bounds kickoff_returner_player_id  \
# 561                    0.0                    0.0                        NaN
#
#     kickoff_returner_player_name  lateral_interception_player_id  \
# 561                          NaN                             NaN
#
#      lateral_interception_player_name  lateral_kickoff_returner_player_id  \
# 561                               NaN                                 NaN
#
#      lateral_kickoff_returner_player_name  lateral_punt_returner_player_id  \
# 561                                   NaN                              NaN
#
#      lateral_punt_returner_player_name lateral_receiver_player_id  \
# 561                                NaN                        NaN
#
#     lateral_receiver_player_name  lateral_reception  lateral_recovery  \
# 561                          NaN                0.0               0.0
#
#      lateral_return  lateral_rush  lateral_rusher_player_id  \
# 561             0.0           0.0                       NaN
#
#      lateral_rusher_player_name  lateral_sack_player_id  \
# 561                         NaN                     NaN
#
#      lateral_sack_player_name location    name  \
# 561                       NaN     Home  J.Goff
#
#                                nfl_api_id  no_huddle  no_score_prob  \
# 561  10160000-0581-8196-873c-fbd4b6a4688f          0       0.002266
#
#      old_game_id  opp_fg_prob  opp_safety_prob  opp_td_prob  order_sequence  \
# 561   2020091312     0.091405         0.001152     0.142873           122.0
#
#      own_kickoff_recovery own_kickoff_recovery_player_id  \
# 561                   0.0                            NaN
#
#     own_kickoff_recovery_player_name  own_kickoff_recovery_td  pass  \
# 561                              NaN                      0.0     1
#
#      pass_attempt pass_defense_1_player_id pass_defense_1_player_name  \
# 561           1.0                      NaN                        NaN
#
#     pass_defense_2_player_id pass_defense_2_player_name pass_length  \
# 561                      NaN                        NaN       short
#
#     pass_location  pass_touchdown  passer  \
# 561          left             0.0  J.Goff
#
#                                 passer_id  passer_jersey_number  \
# 561  32013030-2d30-3033-3331-30361d564889                  16.0
#
#                          passer_player_id passer_player_name  penalty  \
# 561  32013030-2d30-3033-3331-30361d564889             J.Goff      0.0
#
#     penalty_player_id penalty_player_name penalty_team penalty_type  \
# 561               NaN                 NaN          NaN          NaN
#
#      penalty_yards  play  play_clock  play_deleted  play_id play_type  \
# 561            NaN     1           1             0      122      pass
#
#     play_type_nfl posteam  posteam_score  posteam_score_post  \
# 561          PASS      LA            0.0                 0.0
#
#      posteam_timeouts_remaining posteam_type  punt_attempt  punt_blocked  \
# 561                         3.0         home           0.0           0.0
#
#      punt_downed  punt_fair_catch  punt_in_endzone  punt_inside_twenty  \
# 561          0.0              0.0              0.0                 0.0
#
#      punt_out_of_bounds punt_returner_player_id punt_returner_player_name  \
# 561                 0.0                     NaN                       NaN
#
#     punter_player_id punter_player_name  qb_dropback    qb_epa  qb_hit  \
# 561              NaN                NaN          1.0  2.425808     0.0
#
#     qb_hit_1_player_id qb_hit_1_player_name qb_hit_2_player_id  \
# 561                NaN                  NaN                NaN
#
#     qb_hit_2_player_name  qb_kneel  qb_scramble  qb_spike  qtr  quarter_end  \
# 561                  NaN         0            0         0    1            0
#
#      quarter_seconds_remaining receiver                           receiver_id  \
# 561                      820.0  R.Woods  32013030-2d30-3033-3034-333120799932
#
#      receiver_jersey_number                    receiver_player_id  \
# 561                    17.0  32013030-2d30-3033-3034-333120799932
#
#     receiver_player_name  replay_or_challenge replay_or_challenge_result  \
# 561              R.Woods                    0                        NaN
#
#      result return_team  return_touchdown  return_yards roof run_gap  \
# 561       3         NaN               0.0           0.0  NaN     NaN
#
#     run_location  rush  rush_attempt  rush_touchdown rusher rusher_id  \
# 561          NaN     0           0.0             0.0    NaN       NaN
#
#      rusher_jersey_number rusher_player_id rusher_player_name  sack  safety  \
# 561                   NaN              NaN                NaN   0.0     0.0
#
#      safety_prob  score_differential  score_differential_post  season  \
# 561     0.004272                 0.0                      0.0    2020
#
#     season_type  series series_result  series_success  shotgun side_of_field  \
# 561         REG       2    First down               1        0           DAL
#
#      solo_tackle               solo_tackle_1_player_id  \
# 561          1.0  32013030-2d30-3033-3330-3833eeb7445b
#
#     solo_tackle_1_player_name solo_tackle_1_team solo_tackle_2_player_id  \
# 561                D.Thompson                DAL                     NaN
#
#     solo_tackle_2_player_name solo_tackle_2_team  sp  special  \
# 561                       NaN                NaN   0        0
#
#      special_teams_play  spread_line st_play_type       stadium stadium_id  \
# 561                   0          1.0          NaN  SoFi Stadium      LAX01
#
#     start_time  success  surface tackle_for_loss_1_player_id  \
# 561   20:20:00      1.0      NaN                         NaN
#
#     tackle_for_loss_1_player_name  tackle_for_loss_2_player_id  \
# 561                           NaN                          NaN
#
#      tackle_for_loss_2_player_name  tackled_for_loss   td_prob td_team  temp  \
# 561                            NaN               0.0  0.473597     NaN   NaN
#
#      third_down_converted  third_down_failed   time time_of_day  timeout  \
# 561                   0.0                0.0  13:40    00:24:58      0.0
#
#     timeout_team  total  total_away_comp_air_epa  total_away_comp_air_wpa  \
# 561          NaN     37                 2.243692                 0.022511
#
#      total_away_comp_yac_epa  total_away_comp_yac_wpa  total_away_epa  \
# 561                -5.615406                -0.106963       -3.733213
#
#      total_away_pass_epa  total_away_pass_wpa  total_away_raw_air_epa  \
# 561            -3.371714            -0.084452                2.243692
#
#      total_away_raw_air_wpa  total_away_raw_yac_epa  total_away_raw_yac_wpa  \
# 561                0.022511               -5.615406               -0.106963
#
#      total_away_rush_epa  total_away_rush_wpa  total_away_score  \
# 561             0.202497            -0.000246                 0
#
#      total_home_comp_air_epa  total_home_comp_air_wpa  \
# 561                -2.243692                -0.022511
#
#      total_home_comp_yac_epa  total_home_comp_yac_wpa  total_home_epa  \
# 561                 5.615406                 0.106963        3.733213
#
#      total_home_pass_epa  total_home_pass_wpa  total_home_raw_air_epa  \
# 561             3.371714             0.084452               -2.243692
#
#      total_home_raw_air_wpa  total_home_raw_yac_epa  total_home_raw_yac_wpa  \
# 561               -0.022511                5.615406                0.106963
#
#      total_home_rush_epa  total_home_rush_wpa  total_home_score  total_line  \
# 561            -0.202497             0.000246                 0        52.0
#
#      touchback  touchdown  two_point_attempt two_point_conv_result  \
# 561          0        0.0                0.0                   NaN
#
#      two_point_conversion_prob  vegas_home_wp  vegas_wp  \
# 561                        0.0        0.57726   0.57726
#
#                                             weather  week  wind        wp  \
# 561  Cloudy Temp: 72° F, Humidity: 64%, Wind: 7 mph     1   NaN  0.597162
#
#           wpa  xyac_epa   xyac_fd  xyac_mean_yardage  xyac_median_yardage  \
# 561  0.069309  1.443571  0.432218          10.150387                  9.0
#
#      xyac_success   yac_epa   yac_wpa  yardline_100  yards_after_catch  \
# 561      0.504996  3.641983  0.082481          46.0               35.0
#
#      yards_gained  ydsnet  ydstogo   yrdln                   uid
# 561          31.0    75.0        6  DAL 46  2020_01_DAL_LA-1-122

# %% [markdown]
# Next thing to do is get a list of images.

# %%
from os import path

# %%
from pathlib import Path

# %%
p = Path('./images')

# %%
 x= p / 'images'

# %%
path2 = untar_data(URLs.MNIST_TINY)

# %%
target_image.reset_index(inplace=True)

# %%
target_image
# Out:
#       shotgun                      uid                           fn
# 559         0      2020_01_DAL_LA-1-77      2020_01_DAL_LA-1-77.png
# 561         0     2020_01_DAL_LA-1-122     2020_01_DAL_LA-1-122.png
# 564         0     2020_01_DAL_LA-1-196     2020_01_DAL_LA-1-196.png
# 567         0     2020_01_DAL_LA-1-296     2020_01_DAL_LA-1-296.png
# 570         0     2020_01_DAL_LA-2-351     2020_01_DAL_LA-2-351.png
# 573         1     2020_01_DAL_LA-2-417     2020_01_DAL_LA-2-417.png
# 579         1     2020_01_DAL_LA-3-560     2020_01_DAL_LA-3-560.png
# 583         1     2020_01_DAL_LA-3-648     2020_01_DAL_LA-3-648.png
# 584         1     2020_01_DAL_LA-3-672     2020_01_DAL_LA-3-672.png
# 586         0     2020_01_DAL_LA-3-717     2020_01_DAL_LA-3-717.png
# 649         0    2020_01_DAL_LA-8-2241    2020_01_DAL_LA-8-2241.png
# 655         0   2020_01_DAL_LA-10-2404   2020_01_DAL_LA-10-2404.png
# 658         1   2020_01_DAL_LA-10-2468   2020_01_DAL_LA-10-2468.png
# 3283        0     2020_02_BUF_MIA-1-41     2020_02_BUF_MIA-1-41.png
# 3287        1    2020_02_BUF_MIA-1-122    2020_02_BUF_MIA-1-122.png
# 3290        1    2020_02_BUF_MIA-2-193    2020_02_BUF_MIA-2-193.png
# 3293        1    2020_02_BUF_MIA-2-260    2020_02_BUF_MIA-2-260.png
# 3296        0    2020_02_BUF_MIA-3-327    2020_02_BUF_MIA-3-327.png
# 3299        1    2020_02_BUF_MIA-3-395    2020_02_BUF_MIA-3-395.png
# 3300        1    2020_02_BUF_MIA-3-419    2020_02_BUF_MIA-3-419.png
# 3301        0    2020_02_BUF_MIA-3-440    2020_02_BUF_MIA-3-440.png
# 3304        1    2020_02_BUF_MIA-3-511    2020_02_BUF_MIA-3-511.png
# 3305        0    2020_02_BUF_MIA-3-546    2020_02_BUF_MIA-3-546.png
# 3308        1    2020_02_BUF_MIA-4-602    2020_02_BUF_MIA-4-602.png
# 3313        0    2020_02_BUF_MIA-4-718    2020_02_BUF_MIA-4-718.png
# 3315        1    2020_02_BUF_MIA-4-766    2020_02_BUF_MIA-4-766.png
# 3344        1   2020_02_BUF_MIA-9-1456   2020_02_BUF_MIA-9-1456.png
# 3345        1   2020_02_BUF_MIA-9-1480   2020_02_BUF_MIA-9-1480.png
# 3352        1   2020_02_BUF_MIA-9-1673   2020_02_BUF_MIA-9-1673.png
# 3416        1  2020_02_BUF_MIA-18-3218  2020_02_BUF_MIA-18-3218.png
# 3417        0  2020_02_BUF_MIA-18-3242  2020_02_BUF_MIA-18-3242.png
# 3421        0  2020_02_BUF_MIA-18-3341  2020_02_BUF_MIA-18-3341.png
# 3424        0  2020_02_BUF_MIA-19-3396  2020_02_BUF_MIA-19-3396.png
# 3426        0  2020_02_BUF_MIA-19-3455  2020_02_BUF_MIA-19-3455.png

# %%
p
# Out:
# Path('images')

# %%
ImageDataLoaders.from_df(target_image,folder='images', fn_col=2,label_col=0)
